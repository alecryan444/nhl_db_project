# %%
import pandas as pd
import requests

# %%
##Game ID
r = requests.get('https://statsapi.web.nhl.com/api/v1/schedule?season=20192020')
j = r.json()

game_list = []

for date in j['dates']:
    dt = date['date']
    for game in date['games']:
        game_num = game['gamePk']
        if game['gameType'] != 'PR':
            game_list.append(game_num)
        else:
            pass

# %%
toi_dict = {}

game_list = ['2019020001']

for game in game_list:
    
    r = requests.get(f'https://statsapi.web.nhl.com/api/v1/game/{game}/feed/live')
    j = r.json()
    
    game_id = j['gamePk']
    
    for i in ['home', 'away']:
        
        team_id = j['liveData']['boxscore']['teams'][i]['team']['id']
        team_name = j['liveData']['boxscore']['teams'][i]['team']['name']
        for k,v in j['liveData']['boxscore']['teams'][i]['players'].items():
            
            player_id = v['person']['id']
            player_name = v['person']['fullName']
            roster_status = v['person']['rosterStatus']
            jersey = v['jerseyNumber']
            try:
                time_on_ice = v['stats']['skaterStats']['timeOnIce']
            except KeyError:
                time_on_ice = ''
            try:
                g_t_on_ice = v['stats']['goalieStats']['timeOnIce']
            except KeyError:
                g_t_on_ice = ''
            
            toi_dict.setdefault(f'gamePk',[]).append(game_id)
            toi_dict.setdefault(f'team_id',[]).append(team_id)
            toi_dict.setdefault(f'team_name',[]).append(team_name)
            toi_dict.setdefault(f'player_id',[]).append(player_id)
            toi_dict.setdefault(f'player_name',[]).append(player_name)
            toi_dict.setdefault(f'jersey',[]).append(jersey)
            toi_dict.setdefault(f'time_on_ice',[]).append(time_on_ice)
            toi_dict.setdefault(f'g_t_on_ice',[]).append(g_t_on_ice)
            toi_dict.setdefault(f'roster_status',[]).append(roster_status)

# %%
df = pd.DataFrame(toi_dict)

# %%
#Combining toi metrics
df['time_on_ice'] = df['time_on_ice'] + df['g_t_on_ice']
df.drop('g_t_on_ice', axis = 1, inplace= True)

# %%
df
# Out:
#         gamePk  team_id            team_name  player_id          player_name  \
# 0   2019020001       10  Toronto Maple Leafs    8477939     William Nylander
# 1   2019020001       10  Toronto Maple Leafs    8475718          Justin Holl
# 2   2019020001       10  Toronto Maple Leafs    8476406       Nicholas Shore
# 3   2019020001       10  Toronto Maple Leafs    8476879            Cody Ceci
# 4   2019020001       10  Toronto Maple Leafs    8475716      Martin Marincin
# 5   2019020001       10  Toronto Maple Leafs    8476853        Morgan Rielly
# 6   2019020001       10  Toronto Maple Leafs    8477953      Kasperi Kapanen
# 7   2019020001       10  Toronto Maple Leafs    8479318      Auston Matthews
# 8   2019020001       10  Toronto Maple Leafs    8478857      Dmytro Timashov
# 9   2019020001       10  Toronto Maple Leafs    8481624        Ilya Mikheyev
# 10  2019020001       10  Toronto Maple Leafs    8475166         John Tavares
# 11  2019020001       10  Toronto Maple Leafs    8474162          Jake Muzzin
# 12  2019020001       10  Toronto Maple Leafs    8477512    Frederik Gauthier
# 13  2019020001       10  Toronto Maple Leafs    8475883    Frederik Andersen
# 14  2019020001       10  Toronto Maple Leafs    8477341     Andreas Johnsson
# 15  2019020001       10  Toronto Maple Leafs    8477021    Alexander Kerfoot
# 16  2019020001       10  Toronto Maple Leafs    8479675         Trevor Moore
# 17  2019020001       10  Toronto Maple Leafs    8475197         Tyson Barrie
# 18  2019020001       10  Toronto Maple Leafs    8480043    Timothy Liljegren
# 19  2019020001       10  Toronto Maple Leafs    8478483      Mitchell Marner
# 20  2019020001       10  Toronto Maple Leafs    8469455         Jason Spezza
# 21  2019020001       10  Toronto Maple Leafs    8480873        Rasmus Sandin
# 22  2019020001        9      Ottawa Senators    8467950       Craig Anderson
# 23  2019020001        9      Ottawa Senators    8480073      Erik Brannstrom
# 24  2019020001        9      Ottawa Senators    8476919        Chris Tierney
# 25  2019020001        9      Ottawa Senators    8477407      Anthony Duclair
# 26  2019020001        9      Ottawa Senators    8476419  Jean-Gabriel Pageau
# 27  2019020001        9      Ottawa Senators    8468493          Ron Hainsey
# 28  2019020001        9      Ottawa Senators    8474697      Mark Borowiecki
# 29  2019020001        9      Ottawa Senators    8471676           Bobby Ryan
# 30  2019020001        9      Ottawa Senators    8474589          Tyler Ennis
# 31  2019020001        9      Ottawa Senators    8479458       Nikita Zaitsev
# 32  2019020001        9      Ottawa Senators    8477015         Connor Brown
# 33  2019020001        9      Ottawa Senators    8478400          Colin White
# 34  2019020001        9      Ottawa Senators    8478488        Filip Chlapik
# 35  2019020001        9      Ottawa Senators    8480801        Brady Tkachuk
# 36  2019020001        9      Ottawa Senators    8477149       Scott Sabourin
# 37  2019020001        9      Ottawa Senators    8478469        Thomas Chabot
# 38  2019020001        9      Ottawa Senators    8480208      Drake Batherson
# 39  2019020001        9      Ottawa Senators    8474597        Cody Goloubef
# 40  2019020001        9      Ottawa Senators    8473573       Artem Anisimov
# 41  2019020001        9      Ottawa Senators    8476331         Dylan DeMelo
# 42  2019020001        9      Ottawa Senators    8474571       Mikkel Boedker
#
#    jersey time_on_ice roster_status
# 0      88       17:05             Y
# 1       3                         Y
# 2      26        8:33             Y
# 3      83       22:01             Y
# 4      52       13:46             Y
# 5      44       25:37             Y
# 6      24       18:02             Y
# 7      34       18:26             Y
# 8      41        8:50             Y
# 9      65       15:16             Y
# 10     91       18:13             Y
# 11      8       22:06             Y
# 12     33        9:29             Y
# 13     31       59:51             Y
# 14     18       17:22             Y
# 15     15       14:58             Y
# 16     42       16:22             Y
# 17     94       19:32             Y
# 18     37                         N
# 19     16       19:33             Y
# 20     19                         Y
# 21     38        8:58             N
# 22     41       58:27             Y
# 23     26       15:57             Y
# 24     71       17:41             Y
# 25     10       16:53             Y
# 26     44       13:12             Y
# 27     81       17:33             Y
# 28     74       15:47             Y
# 29      9       15:16             Y
# 30     63       19:27             Y
# 31     22       23:59             Y
# 32     28       18:05             Y
# 33     36       16:17             I
# 34     78        5:20             Y
# 35      7       17:32             Y
# 36     49        8:27             I
# 37     72       24:50             Y
# 38     19       11:26             N
# 39     29                         Y
# 40     51       19:40             Y
# 41      2       16:01             Y
# 42     89                         Y

# %%
#engine = sqlalchemy.create_engine('mysql+pymysql://root:password@localhost:3306/nhl_db')
#final_df.to_sql(name='f_game_play_players', con=engine, if_exists='append', index=False)
