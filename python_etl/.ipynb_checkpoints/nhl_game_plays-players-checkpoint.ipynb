# %%
import pandas as pd
import requests 
import sqlalchemy

pd.set_option('display.max_columns', 500)

# %%
##Game ID
r = requests.get('https://statsapi.web.nhl.com/api/v1/schedule?season=20182019')
j = r.json()

game_list = []

for date in j['dates']:
    dt = date['date']
    for game in date['games']:
        game_num = game['gamePk']
        if game['gameType'] != 'PR':
            game_list.append(game_num)
        else:
            pass

# %%
df_list = []

game_list = ['2018020001']

for game in game_list:
    r = requests.get(f"https://statsapi.web.nhl.com/api/v1/game/{game}/feed/live")
    j = r.json()
    
    print(game)
    try:
        play_dict = {}
        for i in list(range(len(j['liveData']['plays']['allPlays']))):


                game_type = j['gameData']['game']['type'] 


                for key, val in j['liveData']['plays']['allPlays'][i].items():
                    event_id = j['liveData']['plays']['allPlays'][i]['about']['eventIdx']
                    event_code = j['liveData']['plays']['allPlays'][i]['result']['eventCode']
                    try:
                        team = j['liveData']['plays']['allPlays'][i]['team']['id']
                    except KeyError:
                        team = ''
                    
                    if key == 'players':
                        for player in val:
                            pt = player['playerType']
                            p_id = player['player']['id']
                            fn = player['player']['fullName']
                            play_dict.setdefault(f'playerType', []).append(pt)
                            play_dict.setdefault(f'playerId', []).append(p_id)
                            play_dict.setdefault(f'eventIdx', []).append(event_id)
                            play_dict.setdefault(f'gameType', []).append(game_type)
                            play_dict.setdefault(f'gamePk', []).append(game)
                            play_dict.setdefault(f'player_name',[]).append(fn)
                            play_dict.setdefault(f'eventCode',[]).append(event_code)
                            play_dict.setdefault(f'team_id',[]).append(team)
                    else:
                        pass 
                        
                        


        df = pd.DataFrame(play_dict)
        df['play_id'] = df['gamePk'].astype(str) + "_" + df['eventIdx'].astype(str)
        df_list.append(df)
    except KeyError:
        pass
# Out:
# 2018020001

# %%
final_df = pd.concat(df_list)

# %%
final_df = final_df[['play_id', 'gamePk', 'player_name','playerType', 'playerId', 'eventIdx', 'gameType', 'eventCode', 'team_id']]

# %%
final_df
# Out:
#             play_id      gamePk         player_name playerType  playerId  \
# 0      2018020001_3  2018020001            Max Domi     Winner   8477503
# 1      2018020001_3  2018020001     Auston Matthews      Loser   8479318
# 2      2018020001_4  2018020001    Artturi Lehkonen    Shooter   8477476
# 3      2018020001_4  2018020001   Frederik Andersen     Goalie   8475883
# 4      2018020001_5  2018020001       Morgan Rielly    Shooter   8476853
# 5      2018020001_5  2018020001         Carey Price     Goalie   8471679
# 6      2018020001_6  2018020001   Brendan Gallagher    Shooter   8475848
# 7      2018020001_6  2018020001   Frederik Andersen     Goalie   8475883
# 8      2018020001_8  2018020001         Nazem Kadri     Winner   8475172
# 9      2018020001_8  2018020001     Phillip Danault      Loser   8476479
# 10     2018020001_9  2018020001        John Tavares    Blocker   8475166
# 11     2018020001_9  2018020001  Jesperi Kotkaniemi    Shooter   8480829
# ...

# %%
#engine = sqlalchemy.create_engine('mysql+pymysql://root:password@localhost:3306/nhl_db')
#final_df.to_sql(name='f_game_play_players', con=engine, if_exists='append', index=False)

# %%
r = requests.get(f"https://statsapi.web.nhl.com/api/v1/game/{game}/feed/live")
j = r.json()

# %%
j['s']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-6f656cf1fc67> in <module>
# ----> 1 j['stats']
#
# KeyError: 'stats'
